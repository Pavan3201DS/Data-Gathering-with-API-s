# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavan3201DS/Data-Gathering-with-API-s/blob/main/Data_gathering_(Movies).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import requests

# %% [markdown]
# Importing response from the URL

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  129             Spirited Away
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23     110.607
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     102.381
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      69.864
# 3  The true story of how businessman Oskar Schind...   1993-12-15      69.412
# 4  A young girl, Chihiro, becomes trapped in a st...   2001-07-20      90.074
#
#    vote_average  vote_count
# 0         8.704       25748
# 1         8.695       19563
# 2         8.575       11816
# 3         8.565       15204
# 4         8.539       15608

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Hitting the same URL for 428 times , this will atleast take a minute...

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# <ipython-input-11-1d9b35f7ce34>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-11-1d9b35f7ce34>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-11-1d9b35f7ce34>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-11-1d9b35f7ce34>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %% [markdown]
# Sample of data fetched from API

# %%
df
# Out:
#          id                     title  \
# 0       278  The Shawshank Redemption
# 1       238             The Godfather
# 2       240     The Godfather Part II
# 3       424          Schindler's List
# 4       129             Spirited Away
# ...     ...                       ...
# 8555  52124            Me and Marilyn
# 8556  86868     Would I Lie to You? 3
# 8557  10923          Agent Cody Banks
# 8558  73861            A Serbian Film
# 8559   4257             Scary Movie 4
#
#                                                overview release_date  \
# 0     Framed in the 1940s for the double murder of h...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# ...                                                 ...          ...
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %% [markdown]
# Converting the data into CSV

# %%
df.to_csv('movies.csv')
